# %%
import pandas as pd


df = pd.read_csv("1_Joseph_max.csv", on_bad_lines='skip')
df2 = df['EMG RMS 1 Time Series (s)']
#df3 = df['EMG RMS 1 (mV) ']
print(df)
# Out:
#       EMG RMS 1 Time Series (s)  EMG RMS 1 (mV)  ACC X Time Series (s)
# 0                           NaN     148.1481 Hz                         \
# 1                       0.00000       0.2403618                      0
# 2                       0.00675       0.1762057               0.003375
# 3                       0.01350       0.1710677                0.00675
# 4                       0.02025       0.1713046               0.010125
# ...                         ...             ...                    ...
# 6540                        NaN                              22.069125
# 6541                        NaN                                22.0725
# 6542                        NaN                              22.075875
# 6543                        NaN                               22.07925
# 6544                        NaN                              22.082625
#
#          ACC X (G)  ACC Y Time Series (s)     ACC Y (G)
# 0      296.2963 Hz                          296.2963 Hz  \
# ...
